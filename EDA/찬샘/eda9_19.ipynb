# %%
#기본설정

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_row',500)

# %%
# !pip install pyarrow

# %%
df = pd.read_parquet('pre_train_201601.parquet')

# %%
df_1 = pd.read_csv('AT_TSALET_ALL_201601.csv')

# %%
df_1['PUM_NM'].nunique()
# Out:
# 261

# %%
df_1_1=df_1[df_1['PUM_NM']=='주키니']
df_1_1['ave']= df_1_1['TOT_AMT']/df_1_1['TOT_QTY']
df_1_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/packchansaem/Desktop/project/maket_kurly/eda9_19.ipynb Cell 6' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/packchansaem/Desktop/project/maket_kurly/eda9_19.ipynb#ch0000005?line=0'>1</a> df_1_1=df_1[df_1['PUM_NM']=='주키니']
#       <a href='vscode-notebook-cell:/Users/packchansaem/Desktop/project/maket_kurly/eda9_19.ipynb#ch0000005?line=1'>2</a> df_1_1['ave']= df_1_1['TOT_AMT']/df_1_1['TOT_QTY']
#       <a href='vscode-notebook-cell:/Users/packchansaem/Desktop/project/maket_kurly/eda9_19.ipynb#ch0000005?line=2'>3</a> df_1_1
#
# NameError: name 'df_1' is not defined

# %%
df_1_1[df_1_1['ave']>10000]
# Out:
#          SALEDATE WHSAL_NM   CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM SIZE_NM  \
# 38734    20160109   인천삼산도매     경인농산     배추     우거지     kg     상자       .
# 130740   20160107   인천삼산도매     경인농산     배추     우거지     kg     상자       .
# 150676   20160106   울산도매시장   울산중앙청과     배추     쌈배추     kg     상자       .
# 150727   20160106   울산도매시장   울산중앙청과     배추     쌈배추     kg     상자       .
# 178652   20160106   인천삼산도매     경인농산     배추     우거지     kg     상자       .
# ...           ...      ...      ...    ...     ...    ...    ...     ...
# 2463255  20160130   천안도매시장  천안농협(공)     배추    기타배추     kg     상자       .
# 2463256  20160130   천안도매시장  천안농협(공)     배추    기타배추     kg     상자       .
# 2506408  20160122   서울가락도매     동화청과     배추     쌈배추     kg     상자       .
# 2573264  20160126   서울가락도매     동화청과     배추     쌈배추     kg     상자       .
# 2627644  20160128   서울가락도매     동화청과     배추     쌈배추     kg     상자       .
#
#         LV_NM   SAN_NM  DANQ  QTY     COST  TOT_QTY  TOT_AMT      ave
# ...

# %%
df
# Out:
#          SALEDATE WHSAL_NM   CMP_NM PUM_NM LV_NM   SIZE_NM    SAN_NM  DANQ  \
# 0      2016-01-02   광주각화도매  광주원협(공)    토마토     상        2개    전남 장성군  10.0
# 1      2016-01-02   광주각화도매  광주원협(공)    토마토     상  1개(내_뿌리)    전남 장성군  10.0
# 2      2016-01-02   광주각화도매  광주원협(공)    토마토    4등        4개    전남 장성군  10.0
# 3      2016-01-02   광주각화도매  광주원협(공)    토마토    보통        3개    전남 장성군  10.0
# 4      2016-01-02   광주각화도매  광주원협(공)    토마토     상        2개    전남 장성군  10.0
# ...           ...      ...      ...    ...   ...       ...       ...   ...
# 569141 2016-01-31   울산도매시장   울산중앙청과     깻잎     .         .  경상남도 밀양시   2.0
# 569142 2016-01-31   울산도매시장   울산중앙청과     깻잎     .         .  경상남도 밀양시   2.0
# 569143 2016-01-31   울산도매시장   울산중앙청과     깻잎     .         .  경상남도 밀양시   2.0
# 569144 2016-01-31   울산도매시장   울산중앙청과     깻잎     .         .  경상남도 밀양시   2.0
# 569145 2016-01-31   울산도매시장   울산중앙청과     깻잎     .         .  경상남도 밀양시   2.0
#
#        DAN_NM  QTY* POJ_NM  TOT_QTY    COST*  TOT_AMT*
# ...

# %%
df_1
# Out:
#          SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM SIZE_NM LV_NM  \
# 0        20160109   부산엄궁도매   부산청과     감귤     조생귤     kg     상자       .    보통
# 1        20160109   부산엄궁도매   부산청과     감귤     조생귤     kg     상자       .    보통
# 2        20160109   부산엄궁도매   부산청과     감귤     조생귤     kg     상자       .     특
# 3        20160109   부산엄궁도매   부산청과     감귤     조생귤     kg     상자       .     특
# 4        20160109   부산엄궁도매   부산청과     감귤     조생귤     kg     상자       .    보통
# ...           ...      ...    ...    ...     ...    ...    ...     ...   ...
# 2700791  20160130   서울강서도매   강서청과      배      신고     kg      .       .     .
# 2700792  20160130   서울강서도매   강서청과      배      신고     kg      .       .     .
# 2700793  20160130   서울강서도매   강서청과      배      신고     kg      .       .     .
# 2700794  20160130   서울강서도매   강서청과      배      신고     kg      .       .     .
# 2700795  20160130   서울강서도매   강서청과      배      신고     kg      .       .     .
#
# ...

# %%
df_2=df_1[df_1['PUM_NM']=='토마토']
df_2[df_2['WHSAL_NM']=='광주각화도매']['SALEDATE'].unique()
# Out:
# array([20160109, 20160108, 20160107, 20160106, 20160105, 20160104,
#        20160102, 20160120, 20160119, 20160118, 20160116, 20160115,
#        20160114, 20160113, 20160112, 20160111, 20160130, 20160129,
#        20160128, 20160127, 20160126, 20160125, 20160123, 20160122,
#        20160121])

# %%
df_3=df_2[df_2['WHSAL_NM']=='광주각화도매']
df_3[df_3['SAN_NM']=='전남 장성군']
# Out:
#          SALEDATE WHSAL_NM   CMP_NM PUM_NM  KIND_NM DAN_NM POJ_NM SIZE_NM  \
# 35044    20160109   광주각화도매     광주청과    토마토  토마토(일반)     kg     상자       .
# 35045    20160109   광주각화도매     광주청과    토마토  토마토(일반)     kg     상자       .
# 35046    20160109   광주각화도매     광주청과    토마토  토마토(일반)     kg     상자       .
# 35047    20160109   광주각화도매     광주청과    토마토  토마토(일반)     kg     상자       .
# 35048    20160109   광주각화도매     광주청과    토마토  토마토(일반)     kg     상자       .
# ...           ...      ...      ...    ...      ...    ...    ...     ...
# 2450518  20160130   광주각화도매  광주원협(공)    토마토    완숙토마토     kg     상자      2개
# 2450519  20160130   광주각화도매  광주원협(공)    토마토    완숙토마토     kg     상자      3개
# 2450520  20160130   광주각화도매  광주원협(공)    토마토    완숙토마토     kg     상자      4개
# 2450521  20160130   광주각화도매  광주원협(공)    토마토    완숙토마토     kg     상자      5개
# 2450522  20160130   광주각화도매  광주원협(공)    토마토    완숙토마토     kg     상자      6개
#
#         LV_NM  SAN_NM  DANQ  QTY     COST  TOT_QTY  TOT_AMT
# ...

# %%
df_1['SALEDATE'] = pd.to_datetime(df_1['SALEDATE'],format="%Y%m%d")
con1=df_1['PUM_NM']=='배추'
pum1=df_1.loc[con1]
pum1_1=pum1[['SALEDATE','COST']]
pum1_1.index=pum1_1['SALEDATE']
pum1_1.set_index('SALEDATE',inplace=True)
plt.figure(figsize= [10,5])
sns.lineplot(data=pum1, x='SALEDATE',y='COST')
# Out:
# <AxesSubplot:xlabel='SALEDATE', ylabel='COST'>

# %%
con1=df['PUM_NM']=='배추'
pum1=df.loc[con1]
pum1_1=pum1[['SALEDATE','COST*']]
pum1_1.index=pum1_1['SALEDATE']
pum1_1.set_index('SALEDATE',inplace=True)
plt.figure(figsize= [10,5])
sns.lineplot(data=pum1, x='SALEDATE',y='COST*')
# Out:
# <AxesSubplot:xlabel='SALEDATE', ylabel='COST*'>

# %%
con2=df['PUM_NM']=='배추'
pum2=df.loc[con2]
#pum2[pum2['SALEDATE']=='2016-01-02']
pum2.groupby(by=['SALEDATE']).sum()
# Out:
#                DANQ    QTY*     TOT_QTY       COST*   TOT_AMT*
# SALEDATE
# 2016-01-02   1178.0    8164    80860.00    582065.0   27212050
# 2016-01-04  12548.5  150280  1422742.50  11357683.0  680347468
# 2016-01-05  11264.3  122115  1156791.00   9333504.0  512095448
# 2016-01-06  10497.7  107808  1026407.50   8506242.0  454244884
# 2016-01-07  11322.7  110612  1020925.00   8716942.0  457876577
# 2016-01-08  10036.8  100230   933055.00   7389970.0  392257821
# 2016-01-09   8056.4   73721   684451.00   5230470.0  266750404
# 2016-01-11  11725.6  117587  1136516.00   9029445.0  454884730
# 2016-01-12   9202.2   75897   719120.10   6899453.0  312757725
# 2016-01-13   7480.6   68113   642654.00   5888599.0  276379281
# 2016-01-14   8042.5   80789   768445.90   5963099.0  338947109
# 2016-01-15   9271.7   83435   793655.00   7313228.0  357586250
# 2016-01-16   7009.6   57753   531832.10   5340418.0  243971349
# 2016-01-18  12808.6  117289  1104684.00  10336696.0  526369529
# ...

# %%
con2=df_1['PUM_NM']=='배추'
pum2=df_1.loc[con2]
#pum2[pum2['SALEDATE']=='2016-01-02']
pum2.groupby(by=['SALEDATE']).sum()
# Out:
#                DANQ     QTY        COST     TOT_QTY    TOT_AMT
# SALEDATE
# 2016-01-02   1178.0    8164    582065.0    80860.00   27212050
# 2016-01-04  12548.5  150280  11357683.0  1422742.50  680347468
# 2016-01-05  11264.3  122115   9333504.0  1156791.00  512095448
# 2016-01-06  10497.7  107808   8506242.0  1026407.50  454244884
# 2016-01-07  11322.7  110612   8716942.0  1020925.00  457876577
# 2016-01-08  10036.8  100230   7389970.0   933055.00  392257821
# 2016-01-09   8056.4   73721   5230470.0   684451.00  266750404
# 2016-01-11  11725.6  117587   9029445.0  1136516.00  454884730
# 2016-01-12   9202.2   75897   6899453.0   719120.10  312757725
# 2016-01-13   7480.6   68113   5888599.0   642654.00  276379281
# 2016-01-14   8042.5   80789   5963099.0   768445.90  338947109
# 2016-01-15   9271.7   83435   7313228.0   793655.00  357586250
# 2016-01-16   7009.6   57753   5340418.0   531832.10  243971349
# 2016-01-18  12808.6  117289  10336696.0  1104684.00  526369529
# ...

# %%
 199551384.0
    199551384.0
