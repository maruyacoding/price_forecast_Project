# %%
# 4주 예측
from preprocessing4 import *

# %%
df = pd.read_parquet('..\프로젝트 data\my_modeling_data2.parquet')

# %%
my = select_pum2(df, '사과', 7)
x_columns = list(my.columns)
x_columns.remove('SALEDATE')
x_columns.remove('4week')
x_columns
# Out:
# ['TOT_AMT',
#  'TOT_QTY',
#  'mean_price',
#  'p_lag_1',
#  'p_lag_2',
#  'p_lag_3',
#  'p_lag_4',
#  'p_lag_5',
#  'p_lag_6',
#  'p_lag_7',
#  'resid',
#  'trend',
#  'season',
#  'mean_price_5',
#  'mean_price_30',
#  'ratio_mean_price_5_30',
#  'std_price_5',
#  'std_price_30',
#  'ratio_std_price_5_30']

# %%
for pum in df.PUM_NM.unique() :
    modeling2(df, pum, 7, x_columns)
# Out:
# (1138, 19) (1138,) (293, 19) (293,)
# LinearRegression Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 262.94it/s]
# First train_day: 0	 Last train_day: 192
# First val_day: 193	 Last val_day: 381
# ----------------------------------------
# First train_day: 0	 Last train_day: 381
# First val_day: 382	 Last val_day: 570
# ----------------------------------------
# First train_day: 0	 Last train_day: 570
# First val_day: 571	 Last val_day: 759
# ----------------------------------------
# First train_day: 0	 Last train_day: 759
# First val_day: 760	 Last val_day: 948
# ----------------------------------------
# First train_day: 0	 Last train_day: 948
# First val_day: 949	 Last val_day: 1137
# ----------------------------------------
# 1 FOLDS: LinearRegression MAPE: 0.2251
# 2 FOLDS: LinearRegression MAPE: 0.1569
# 3 FOLDS: LinearRegression MAPE: 0.1189
# 4 FOLDS: LinearRegression MAPE: 0.1364
# 5 FOLDS: LinearRegression MAPE: 0.1864
#
# LinearRegression mean MAPE: 0.1647
# ========================================
# (1138, 19) (1138,) (293, 19) (293,)
# Ridge Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 239.89it/s]
# First train_day: 0	 Last train_day: 192
# First val_day: 193	 Last val_day: 381
# ----------------------------------------
# First train_day: 0	 Last train_day: 381
# First val_day: 382	 Last val_day: 570
# ----------------------------------------
# First train_day: 0	 Last train_day: 570
# First val_day: 571	 Last val_day: 759
# ----------------------------------------
# First train_day: 0	 Last train_day: 759
# First val_day: 760	 Last val_day: 948
# ----------------------------------------
# First train_day: 0	 Last train_day: 948
# First val_day: 949	 Last val_day: 1137
# ----------------------------------------
# 1 FOLDS: Ridge MAPE: 0.1888
# 2 FOLDS: Ridge MAPE: 0.1572
# 3 FOLDS: Ridge MAPE: 0.1151
# 4 FOLDS: Ridge MAPE: 0.1340
# 5 FOLDS: Ridge MAPE: 0.1854
#
# Ridge mean MAPE: 0.1561
# ========================================
# (1138, 19) (1138,) (293, 19) (293,)
# Lasso Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 148.89it/s]
# First train_day: 0	 Last train_day: 192
# First val_day: 193	 Last val_day: 381
# ----------------------------------------
# First train_day: 0	 Last train_day: 381
# First val_day: 382	 Last val_day: 570
# ----------------------------------------
# First train_day: 0	 Last train_day: 570
# First val_day: 571	 Last val_day: 759
# ----------------------------------------
# First train_day: 0	 Last train_day: 759
# First val_day: 760	 Last val_day: 948
# ----------------------------------------
# First train_day: 0	 Last train_day: 948
# First val_day: 949	 Last val_day: 1137
# ----------------------------------------
# 1 FOLDS: Lasso MAPE: 0.2054
# 2 FOLDS: Lasso MAPE: 0.1589
# 3 FOLDS: Lasso MAPE: 0.1136
# 4 FOLDS: Lasso MAPE: 0.1304
# 5 FOLDS: Lasso MAPE: 0.1834
#
# Lasso mean MAPE: 0.1583
# ========================================
# (1138, 19) (1138,) (293, 19) (293,)
# ElasticNet Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 293.85it/s]
# First train_day: 0	 Last train_day: 192
# First val_day: 193	 Last val_day: 381
# ----------------------------------------
# First train_day: 0	 Last train_day: 381
# First val_day: 382	 Last val_day: 570
# ----------------------------------------
# First train_day: 0	 Last train_day: 570
# First val_day: 571	 Last val_day: 759
# ----------------------------------------
# First train_day: 0	 Last train_day: 759
# First val_day: 760	 Last val_day: 948
# ----------------------------------------
# First train_day: 0	 Last train_day: 948
# First val_day: 949	 Last val_day: 1137
# ----------------------------------------
# 1 FOLDS: ElasticNet MAPE: 0.1394
# 2 FOLDS: ElasticNet MAPE: 0.1582
# 3 FOLDS: ElasticNet MAPE: 0.1034
# 4 FOLDS: ElasticNet MAPE: 0.1396
# 5 FOLDS: ElasticNet MAPE: 0.1679
#
# ElasticNet mean MAPE: 0.1417
# ========================================
# (1138, 19) (1138,) (293, 19) (293,)
# DecisionTreeRegressor Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 105.56it/s]
# First train_day: 0	 Last train_day: 192
# First val_day: 193	 Last val_day: 381
# ----------------------------------------
# First train_day: 0	 Last train_day: 381
# First val_day: 382	 Last val_day: 570
# ----------------------------------------
# First train_day: 0	 Last train_day: 570
# First val_day: 571	 Last val_day: 759
# ----------------------------------------
# First train_day: 0	 Last train_day: 759
# First val_day: 760	 Last val_day: 948
# ----------------------------------------
# First train_day: 0	 Last train_day: 948
# First val_day: 949	 Last val_day: 1137
# ----------------------------------------
# 1 FOLDS: DecisionTreeRegressor MAPE: 0.1879
# 2 FOLDS: DecisionTreeRegressor MAPE: 0.2041
# 3 FOLDS: DecisionTreeRegressor MAPE: 0.1394
# 4 FOLDS: DecisionTreeRegressor MAPE: 0.1967
# 5 FOLDS: DecisionTreeRegressor MAPE: 0.2514
#
# DecisionTreeRegressor mean MAPE: 0.1959
# ========================================
# (1138, 19) (1138,) (293, 19) (293,)
# RandomForestRegressor Cross Validations...:   0%|          | 0/10 [00:00<?, ?it/s]
# First train_day: 0	 Last train_day: 192
# First val_day: 193	 Last val_day: 381
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  10%|█         | 1/10 [00:00<00:01,  4.65it/s]
# First train_day: 0	 Last train_day: 381
# First val_day: 382	 Last val_day: 570
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  20%|██        | 2/10 [00:00<00:02,  3.41it/s]
# First train_day: 0	 Last train_day: 570
# First val_day: 571	 Last val_day: 759
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  30%|███       | 3/10 [00:01<00:02,  2.67it/s]
# First train_day: 0	 Last train_day: 759
# First val_day: 760	 Last val_day: 948
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  40%|████      | 4/10 [00:01<00:02,  2.03it/s]
# First train_day: 0	 Last train_day: 948
# First val_day: 949	 Last val_day: 1137
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  50%|█████     | 5/10 [00:02<00:02,  1.99it/s]
# 1 FOLDS: RandomForestRegressor MAPE: 0.1739
# 2 FOLDS: RandomForestRegressor MAPE: 0.1952
# 3 FOLDS: RandomForestRegressor MAPE: 0.1429
# 4 FOLDS: RandomForestRegressor MAPE: 0.1368
# 5 FOLDS: RandomForestRegressor MAPE: 0.2218
#
# RandomForestRegressor mean MAPE: 0.1741
# ========================================
# (1138, 19) (1138,) (293, 19) (293,)
# XGBRegressor Cross Validations...:  20%|██        | 2/10 [00:00<00:00, 13.97it/s]
# First train_day: 0	 Last train_day: 192
# First val_day: 193	 Last val_day: 381
# ----------------------------------------
# First train_day: 0	 Last train_day: 381
# First val_day: 382	 Last val_day: 570
# ----------------------------------------
# First train_day: 0	 Last train_day: 570
# First val_day: 571	 Last val_day: 759
# ----------------------------------------
# XGBRegressor Cross Validations...:  40%|████      | 4/10 [00:00<00:00, 10.92it/s]
# First train_day: 0	 Last train_day: 759
# First val_day: 760	 Last val_day: 948
# ----------------------------------------
# First train_day: 0	 Last train_day: 948
# First val_day: 949	 Last val_day: 1137
# ----------------------------------------
# XGBRegressor Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 10.32it/s]
# 1 FOLDS: XGBRegressor MAPE: 0.1639
# 2 FOLDS: XGBRegressor MAPE: 0.1951
# 3 FOLDS: XGBRegressor MAPE: 0.1390
# 4 FOLDS: XGBRegressor MAPE: 0.1556
# 5 FOLDS: XGBRegressor MAPE: 0.2416
#
# XGBRegressor mean MAPE: 0.1790
# ========================================
# (1138, 19) (1138,) (293, 19) (293,)
# LGBMRegressor Cross Validations...:  30%|███       | 3/10 [00:00<00:00, 23.06it/s]
# First train_day: 0	 Last train_day: 192
# First val_day: 193	 Last val_day: 381
# ----------------------------------------
# First train_day: 0	 Last train_day: 381
# First val_day: 382	 Last val_day: 570
# ----------------------------------------
# First train_day: 0	 Last train_day: 570
# First val_day: 571	 Last val_day: 759
# ----------------------------------------
# First train_day: 0	 Last train_day: 759
# First val_day: 760	 Last val_day: 948
# ----------------------------------------
# LGBMRegressor Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 16.82it/s]
# First train_day: 0	 Last train_day: 948
# First val_day: 949	 Last val_day: 1137
# ----------------------------------------
# 1 FOLDS: LGBMRegressor MAPE: 0.1630
# 2 FOLDS: LGBMRegressor MAPE: 0.1731
# 3 FOLDS: LGBMRegressor MAPE: 0.1292
# 4 FOLDS: LGBMRegressor MAPE: 0.1473
# 5 FOLDS: LGBMRegressor MAPE: 0.2369
#
# LGBMRegressor mean MAPE: 0.1699
# ========================================
#                    Model  Score
# 0       LinearRegression   0.16
# 1                  Ridge   0.16
# 2                  Lasso   0.16
# 3             ElasticNet   0.14
# 4  DecisionTreeRegressor   0.20
# 5  RandomForestRegressor   0.17
# 6           XGBRegressor   0.18
# 7          LGBMRegressor   0.17
# (1138, 19) (1138,) (293, 19) (293,)
# LinearRegression Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 279.47it/s]
# First train_day: 0	 Last train_day: 192
# First val_day: 193	 Last val_day: 381
# ----------------------------------------
# First train_day: 0	 Last train_day: 381
# First val_day: 382	 Last val_day: 570
# ----------------------------------------
# First train_day: 0	 Last train_day: 570
# First val_day: 571	 Last val_day: 759
# ----------------------------------------
# First train_day: 0	 Last train_day: 759
# First val_day: 760	 Last val_day: 948
# ----------------------------------------
# First train_day: 0	 Last train_day: 948
# First val_day: 949	 Last val_day: 1137
# ----------------------------------------
# 1 FOLDS: LinearRegression MAPE: 0.3152
# 2 FOLDS: LinearRegression MAPE: 0.5232
# 3 FOLDS: LinearRegression MAPE: 0.3575
# 4 FOLDS: LinearRegression MAPE: 0.5069
# 5 FOLDS: LinearRegression MAPE: 0.4236
#
# LinearRegression mean MAPE: 0.4253
# ========================================
# (1138, 19) (1138,) (293, 19) (293,)
# Ridge Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 296.21it/s]
# First train_day: 0	 Last train_day: 192
# First val_day: 193	 Last val_day: 381
# ----------------------------------------
# First train_day: 0	 Last train_day: 381
# First val_day: 382	 Last val_day: 570
# ----------------------------------------
# First train_day: 0	 Last train_day: 570
# First val_day: 571	 Last val_day: 759
# ----------------------------------------
# First train_day: 0	 Last train_day: 759
# First val_day: 760	 Last val_day: 948
# ----------------------------------------
# First train_day: 0	 Last train_day: 948
# First val_day: 949	 Last val_day: 1137
# ----------------------------------------
# 1 FOLDS: Ridge MAPE: 0.3213
# 2 FOLDS: Ridge MAPE: 0.5275
# 3 FOLDS: Ridge MAPE: 0.3595
# 4 FOLDS: Ridge MAPE: 0.5092
# 5 FOLDS: Ridge MAPE: 0.4247
#
# Ridge mean MAPE: 0.4284
# ========================================
# (1138, 19) (1138,) (293, 19) (293,)
# Lasso Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 148.46it/s]
# First train_day: 0	 Last train_day: 192
# First val_day: 193	 Last val_day: 381
# ----------------------------------------
# First train_day: 0	 Last train_day: 381
# First val_day: 382	 Last val_day: 570
# ----------------------------------------
# First train_day: 0	 Last train_day: 570
# First val_day: 571	 Last val_day: 759
# ----------------------------------------
# First train_day: 0	 Last train_day: 759
# First val_day: 760	 Last val_day: 948
# ----------------------------------------
# First train_day: 0	 Last train_day: 948
# First val_day: 949	 Last val_day: 1137
# ----------------------------------------
# 1 FOLDS: Lasso MAPE: 0.3227
# 2 FOLDS: Lasso MAPE: 0.5346
# 3 FOLDS: Lasso MAPE: 0.3645
# 4 FOLDS: Lasso MAPE: 0.5141
# 5 FOLDS: Lasso MAPE: 0.4292
#
# Lasso mean MAPE: 0.4330
# ========================================
# (1138, 19) (1138,) (293, 19) (293,)
# ElasticNet Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 312.25it/s]
# First train_day: 0	 Last train_day: 192
# First val_day: 193	 Last val_day: 381
# ----------------------------------------
# First train_day: 0	 Last train_day: 381
# First val_day: 382	 Last val_day: 570
# ----------------------------------------
# First train_day: 0	 Last train_day: 570
# First val_day: 571	 Last val_day: 759
# ----------------------------------------
# First train_day: 0	 Last train_day: 759
# First val_day: 760	 Last val_day: 948
# ----------------------------------------
# First train_day: 0	 Last train_day: 948
# First val_day: 949	 Last val_day: 1137
# ----------------------------------------
# 1 FOLDS: ElasticNet MAPE: 0.3600
# 2 FOLDS: ElasticNet MAPE: 0.6098
# 3 FOLDS: ElasticNet MAPE: 0.3969
# 4 FOLDS: ElasticNet MAPE: 0.5869
# 5 FOLDS: ElasticNet MAPE: 0.4530
#
# ElasticNet mean MAPE: 0.4813
# ========================================
# (1138, 19) (1138,) (293, 19) (293,)
# DecisionTreeRegressor Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 108.12it/s]
# First train_day: 0	 Last train_day: 192
# First val_day: 193	 Last val_day: 381
# ----------------------------------------
# First train_day: 0	 Last train_day: 381
# First val_day: 382	 Last val_day: 570
# ----------------------------------------
# First train_day: 0	 Last train_day: 570
# First val_day: 571	 Last val_day: 759
# ----------------------------------------
# First train_day: 0	 Last train_day: 759
# First val_day: 760	 Last val_day: 948
# ----------------------------------------
# First train_day: 0	 Last train_day: 948
# First val_day: 949	 Last val_day: 1137
# ----------------------------------------
# 1 FOLDS: DecisionTreeRegressor MAPE: 0.3801
# 2 FOLDS: DecisionTreeRegressor MAPE: 0.4270
# 3 FOLDS: DecisionTreeRegressor MAPE: 0.3343
# 4 FOLDS: DecisionTreeRegressor MAPE: 0.5456
# 5 FOLDS: DecisionTreeRegressor MAPE: 0.3764
#
# DecisionTreeRegressor mean MAPE: 0.4127
# ========================================
# (1138, 19) (1138,) (293, 19) (293,)
# RandomForestRegressor Cross Validations...:  10%|█         | 1/10 [00:00<00:01,  5.36it/s]
# First train_day: 0	 Last train_day: 192
# First val_day: 193	 Last val_day: 381
# ----------------------------------------
# First train_day: 0	 Last train_day: 381
# First val_day: 382	 Last val_day: 570
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  20%|██        | 2/10 [00:00<00:02,  3.86it/s]
# First train_day: 0	 Last train_day: 570
# First val_day: 571	 Last val_day: 759
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  30%|███       | 3/10 [00:00<00:02,  2.88it/s]
# First train_day: 0	 Last train_day: 759
# First val_day: 760	 Last val_day: 948
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  40%|████      | 4/10 [00:01<00:02,  2.22it/s]
# First train_day: 0	 Last train_day: 948
# First val_day: 949	 Last val_day: 1137
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  50%|█████     | 5/10 [00:02<00:02,  2.16it/s]
# 1 FOLDS: RandomForestRegressor MAPE: 0.3757
# 2 FOLDS: RandomForestRegressor MAPE: 0.4199
# 3 FOLDS: RandomForestRegressor MAPE: 0.3257
# 4 FOLDS: RandomForestRegressor MAPE: 0.5070
# 5 FOLDS: RandomForestRegressor MAPE: 0.3547
#
# RandomForestRegressor mean MAPE: 0.3966
# ========================================
# (1138, 19) (1138,) (293, 19) (293,)
# XGBRegressor Cross Validations...:  20%|██        | 2/10 [00:00<00:00, 14.59it/s]
# First train_day: 0	 Last train_day: 192
# First val_day: 193	 Last val_day: 381
# ----------------------------------------
# First train_day: 0	 Last train_day: 381
# First val_day: 382	 Last val_day: 570
# ----------------------------------------
# First train_day: 0	 Last train_day: 570
# First val_day: 571	 Last val_day: 759
# ----------------------------------------
# XGBRegressor Cross Validations...:  40%|████      | 4/10 [00:00<00:00, 11.76it/s]
# First train_day: 0	 Last train_day: 759
# First val_day: 760	 Last val_day: 948
# ----------------------------------------
# First train_day: 0	 Last train_day: 948
# First val_day: 949	 Last val_day: 1137
# ----------------------------------------
# XGBRegressor Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 11.28it/s]
# 1 FOLDS: XGBRegressor MAPE: 0.3423
# 2 FOLDS: XGBRegressor MAPE: 0.3468
# 3 FOLDS: XGBRegressor MAPE: 0.3307
# 4 FOLDS: XGBRegressor MAPE: 0.4318
# 5 FOLDS: XGBRegressor MAPE: 0.2800
#
# XGBRegressor mean MAPE: 0.3463
# ========================================
# (1138, 19) (1138,) (293, 19) (293,)
# LGBMRegressor Cross Validations...:  30%|███       | 3/10 [00:00<00:00, 27.74it/s]
# First train_day: 0	 Last train_day: 192
# First val_day: 193	 Last val_day: 381
# ----------------------------------------
# First train_day: 0	 Last train_day: 381
# First val_day: 382	 Last val_day: 570
# ----------------------------------------
# First train_day: 0	 Last train_day: 570
# First val_day: 571	 Last val_day: 759
# ----------------------------------------
# First train_day: 0	 Last train_day: 759
# First val_day: 760	 Last val_day: 948
# ----------------------------------------
# First train_day: 0	 Last train_day: 948
# First val_day: 949	 Last val_day: 1137
# ----------------------------------------
# LGBMRegressor Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 19.14it/s]
# 1 FOLDS: LGBMRegressor MAPE: 0.4738
# 2 FOLDS: LGBMRegressor MAPE: 0.4395
# 3 FOLDS: LGBMRegressor MAPE: 0.3482
# 4 FOLDS: LGBMRegressor MAPE: 0.4439
# 5 FOLDS: LGBMRegressor MAPE: 0.2484
#
# LGBMRegressor mean MAPE: 0.3908
# ========================================
#                    Model  Score
# 0       LinearRegression   0.43
# 1                  Ridge   0.43
# 2                  Lasso   0.43
# 3             ElasticNet   0.48
# 4  DecisionTreeRegressor   0.41
# 5  RandomForestRegressor   0.40
# 6           XGBRegressor   0.35
# 7          LGBMRegressor   0.39
# (1138, 19) (1138,) (292, 19) (292,)
# LinearRegression Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 312.22it/s]
# First train_day: 0	 Last train_day: 192
# First val_day: 193	 Last val_day: 381
# ----------------------------------------
# First train_day: 0	 Last train_day: 381
# First val_day: 382	 Last val_day: 570
# ----------------------------------------
# First train_day: 0	 Last train_day: 570
# First val_day: 571	 Last val_day: 759
# ----------------------------------------
# First train_day: 0	 Last train_day: 759
# First val_day: 760	 Last val_day: 948
# ----------------------------------------
# First train_day: 0	 Last train_day: 948
# First val_day: 949	 Last val_day: 1137
# ----------------------------------------
# 1 FOLDS: LinearRegression MAPE: 0.2956
# 2 FOLDS: LinearRegression MAPE: 0.5462
# 3 FOLDS: LinearRegression MAPE: 0.2762
# 4 FOLDS: LinearRegression MAPE: 0.4412
# 5 FOLDS: LinearRegression MAPE: 0.3327
#
# LinearRegression mean MAPE: 0.3783
# ========================================
# (1138, 19) (1138,) (292, 19) (292,)
# Ridge Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 293.87it/s]
# First train_day: 0	 Last train_day: 192
# First val_day: 193	 Last val_day: 381
# ----------------------------------------
# First train_day: 0	 Last train_day: 381
# First val_day: 382	 Last val_day: 570
# ----------------------------------------
# First train_day: 0	 Last train_day: 570
# First val_day: 571	 Last val_day: 759
# ----------------------------------------
# First train_day: 0	 Last train_day: 759
# First val_day: 760	 Last val_day: 948
# ----------------------------------------
# First train_day: 0	 Last train_day: 948
# First val_day: 949	 Last val_day: 1137
# ----------------------------------------
# 1 FOLDS: Ridge MAPE: 0.2684
# 2 FOLDS: Ridge MAPE: 0.5536
# 3 FOLDS: Ridge MAPE: 0.2738
# 4 FOLDS: Ridge MAPE: 0.4428
# 5 FOLDS: Ridge MAPE: 0.3325
#
# Ridge mean MAPE: 0.3742
# ========================================
# (1138, 19) (1138,) (292, 19) (292,)
# Lasso Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 127.15it/s]
# First train_day: 0	 Last train_day: 192
# First val_day: 193	 Last val_day: 381
# ----------------------------------------
# First train_day: 0	 Last train_day: 381
# First val_day: 382	 Last val_day: 570
# ----------------------------------------
# First train_day: 0	 Last train_day: 570
# First val_day: 571	 Last val_day: 759
# ----------------------------------------
# First train_day: 0	 Last train_day: 759
# First val_day: 760	 Last val_day: 948
# ----------------------------------------
# First train_day: 0	 Last train_day: 948
# First val_day: 949	 Last val_day: 1137
# ----------------------------------------
# 1 FOLDS: Lasso MAPE: 0.2723
# 2 FOLDS: Lasso MAPE: 0.5641
# 3 FOLDS: Lasso MAPE: 0.2663
# 4 FOLDS: Lasso MAPE: 0.4609
# 5 FOLDS: Lasso MAPE: 0.3332
#
# Lasso mean MAPE: 0.3794
# ========================================
# (1138, 19) (1138,) (292, 19) (292,)
# ElasticNet Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 356.74it/s]
# First train_day: 0	 Last train_day: 192
# First val_day: 193	 Last val_day: 381
# ----------------------------------------
# First train_day: 0	 Last train_day: 381
# First val_day: 382	 Last val_day: 570
# ----------------------------------------
# First train_day: 0	 Last train_day: 570
# First val_day: 571	 Last val_day: 759
# ----------------------------------------
# First train_day: 0	 Last train_day: 759
# First val_day: 760	 Last val_day: 948
# ----------------------------------------
# First train_day: 0	 Last train_day: 948
# First val_day: 949	 Last val_day: 1137
# ----------------------------------------
# 1 FOLDS: ElasticNet MAPE: 0.1894
# 2 FOLDS: ElasticNet MAPE: 0.5872
# 3 FOLDS: ElasticNet MAPE: 0.2745
# 4 FOLDS: ElasticNet MAPE: 0.5496
# 5 FOLDS: ElasticNet MAPE: 0.4076
#
# ElasticNet mean MAPE: 0.4017
# ========================================
# (1138, 19) (1138,) (292, 19) (292,)
# DecisionTreeRegressor Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 110.64it/s]
# First train_day: 0	 Last train_day: 192
# First val_day: 193	 Last val_day: 381
# ----------------------------------------
# First train_day: 0	 Last train_day: 381
# First val_day: 382	 Last val_day: 570
# ----------------------------------------
# First train_day: 0	 Last train_day: 570
# First val_day: 571	 Last val_day: 759
# ----------------------------------------
# First train_day: 0	 Last train_day: 759
# First val_day: 760	 Last val_day: 948
# ----------------------------------------
# First train_day: 0	 Last train_day: 948
# First val_day: 949	 Last val_day: 1137
# ----------------------------------------
# 1 FOLDS: DecisionTreeRegressor MAPE: 0.4431
# 2 FOLDS: DecisionTreeRegressor MAPE: 0.8963
# 3 FOLDS: DecisionTreeRegressor MAPE: 0.3459
# 4 FOLDS: DecisionTreeRegressor MAPE: 0.3465
# 5 FOLDS: DecisionTreeRegressor MAPE: 0.2902
#
# DecisionTreeRegressor mean MAPE: 0.4644
# ========================================
# (1138, 19) (1138,) (292, 19) (292,)
# RandomForestRegressor Cross Validations...:  10%|█         | 1/10 [00:00<00:01,  5.15it/s]
# First train_day: 0	 Last train_day: 192
# First val_day: 193	 Last val_day: 381
# ----------------------------------------
# First train_day: 0	 Last train_day: 381
# First val_day: 382	 Last val_day: 570
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  20%|██        | 2/10 [00:00<00:02,  3.77it/s]
# First train_day: 0	 Last train_day: 570
# First val_day: 571	 Last val_day: 759
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  30%|███       | 3/10 [00:00<00:02,  2.93it/s]
# First train_day: 0	 Last train_day: 759
# First val_day: 760	 Last val_day: 948
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  40%|████      | 4/10 [00:01<00:02,  2.29it/s]
# First train_day: 0	 Last train_day: 948
# First val_day: 949	 Last val_day: 1137
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  50%|█████     | 5/10 [00:02<00:02,  2.20it/s]
# 1 FOLDS: RandomForestRegressor MAPE: 0.3009
# 2 FOLDS: RandomForestRegressor MAPE: 0.7581
# 3 FOLDS: RandomForestRegressor MAPE: 0.2648
# 4 FOLDS: RandomForestRegressor MAPE: 0.3425
# 5 FOLDS: RandomForestRegressor MAPE: 0.2678
#
# RandomForestRegressor mean MAPE: 0.3868
# ========================================
# (1138, 19) (1138,) (292, 19) (292,)
# XGBRegressor Cross Validations...:  20%|██        | 2/10 [00:00<00:00, 14.91it/s]
# First train_day: 0	 Last train_day: 192
# First val_day: 193	 Last val_day: 381
# ----------------------------------------
# First train_day: 0	 Last train_day: 381
# First val_day: 382	 Last val_day: 570
# ----------------------------------------
# First train_day: 0	 Last train_day: 570
# First val_day: 571	 Last val_day: 759
# ----------------------------------------
# XGBRegressor Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 11.21it/s]
# First train_day: 0	 Last train_day: 759
# First val_day: 760	 Last val_day: 948
# ----------------------------------------
# First train_day: 0	 Last train_day: 948
# First val_day: 949	 Last val_day: 1137
# ----------------------------------------
# 1 FOLDS: XGBRegressor MAPE: 0.3076
# 2 FOLDS: XGBRegressor MAPE: 0.6349
# 3 FOLDS: XGBRegressor MAPE: 0.3085
# 4 FOLDS: XGBRegressor MAPE: 0.3486
# 5 FOLDS: XGBRegressor MAPE: 0.2759
#
# XGBRegressor mean MAPE: 0.3751
# ========================================
# (1138, 19) (1138,) (292, 19) (292,)
# LGBMRegressor Cross Validations...:  30%|███       | 3/10 [00:00<00:00, 26.06it/s]
# First train_day: 0	 Last train_day: 192
# First val_day: 193	 Last val_day: 381
# ----------------------------------------
# First train_day: 0	 Last train_day: 381
# First val_day: 382	 Last val_day: 570
# ----------------------------------------
# First train_day: 0	 Last train_day: 570
# First val_day: 571	 Last val_day: 759
# ----------------------------------------
# First train_day: 0	 Last train_day: 759
# First val_day: 760	 Last val_day: 948
# ----------------------------------------
# First train_day: 0	 Last train_day: 948
# First val_day: 949	 Last val_day: 1137
# ----------------------------------------
# LGBMRegressor Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 18.71it/s]
# 1 FOLDS: LGBMRegressor MAPE: 0.2621
# 2 FOLDS: LGBMRegressor MAPE: 0.6619
# 3 FOLDS: LGBMRegressor MAPE: 0.2862
# 4 FOLDS: LGBMRegressor MAPE: 0.3829
# 5 FOLDS: LGBMRegressor MAPE: 0.2792
#
# LGBMRegressor mean MAPE: 0.3745
# ========================================
#                    Model  Score
# 0       LinearRegression   0.38
# 1                  Ridge   0.37
# 2                  Lasso   0.38
# 3             ElasticNet   0.40
# 4  DecisionTreeRegressor   0.46
# 5  RandomForestRegressor   0.39
# 6           XGBRegressor   0.38
# 7          LGBMRegressor   0.37
# (1134, 19) (1134,) (294, 19) (294,)
# LinearRegression Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 293.86it/s]
# First train_day: 0	 Last train_day: 188
# First val_day: 189	 Last val_day: 377
# ----------------------------------------
# First train_day: 0	 Last train_day: 377
# First val_day: 378	 Last val_day: 566
# ----------------------------------------
# First train_day: 0	 Last train_day: 566
# First val_day: 567	 Last val_day: 755
# ----------------------------------------
# First train_day: 0	 Last train_day: 755
# First val_day: 756	 Last val_day: 944
# ----------------------------------------
# First train_day: 0	 Last train_day: 944
# First val_day: 945	 Last val_day: 1133
# ----------------------------------------
# 1 FOLDS: LinearRegression MAPE: 0.1809
# 2 FOLDS: LinearRegression MAPE: 0.1848
# 3 FOLDS: LinearRegression MAPE: 0.2911
# 4 FOLDS: LinearRegression MAPE: 0.1951
# 5 FOLDS: LinearRegression MAPE: 0.3003
#
# LinearRegression mean MAPE: 0.2304
# ========================================
# (1134, 19) (1134,) (294, 19) (294,)
# Ridge Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 333.05it/s]
# First train_day: 0	 Last train_day: 188
# First val_day: 189	 Last val_day: 377
# ----------------------------------------
# First train_day: 0	 Last train_day: 377
# First val_day: 378	 Last val_day: 566
# ----------------------------------------
# First train_day: 0	 Last train_day: 566
# First val_day: 567	 Last val_day: 755
# ----------------------------------------
# First train_day: 0	 Last train_day: 755
# First val_day: 756	 Last val_day: 944
# ----------------------------------------
# First train_day: 0	 Last train_day: 944
# First val_day: 945	 Last val_day: 1133
# ----------------------------------------
# 1 FOLDS: Ridge MAPE: 0.1798
# 2 FOLDS: Ridge MAPE: 0.1881
# 3 FOLDS: Ridge MAPE: 0.2879
# 4 FOLDS: Ridge MAPE: 0.1910
# 5 FOLDS: Ridge MAPE: 0.2896
#
# Ridge mean MAPE: 0.2273
# ========================================
# (1134, 19) (1134,) (294, 19) (294,)
# Lasso Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 145.82it/s]
# First train_day: 0	 Last train_day: 188
# First val_day: 189	 Last val_day: 377
# ----------------------------------------
# First train_day: 0	 Last train_day: 377
# First val_day: 378	 Last val_day: 566
# ----------------------------------------
# First train_day: 0	 Last train_day: 566
# First val_day: 567	 Last val_day: 755
# ----------------------------------------
# First train_day: 0	 Last train_day: 755
# First val_day: 756	 Last val_day: 944
# ----------------------------------------
# First train_day: 0	 Last train_day: 944
# First val_day: 945	 Last val_day: 1133
# ----------------------------------------
# 1 FOLDS: Lasso MAPE: 0.1738
# 2 FOLDS: Lasso MAPE: 0.1876
# 3 FOLDS: Lasso MAPE: 0.2880
# 4 FOLDS: Lasso MAPE: 0.1980
# 5 FOLDS: Lasso MAPE: 0.2785
#
# Lasso mean MAPE: 0.2251
# ========================================
# (1134, 19) (1134,) (294, 19) (294,)
# ElasticNet Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 325.44it/s]
# First train_day: 0	 Last train_day: 188
# First val_day: 189	 Last val_day: 377
# ----------------------------------------
# First train_day: 0	 Last train_day: 377
# First val_day: 378	 Last val_day: 566
# ----------------------------------------
# First train_day: 0	 Last train_day: 566
# First val_day: 567	 Last val_day: 755
# ----------------------------------------
# First train_day: 0	 Last train_day: 755
# First val_day: 756	 Last val_day: 944
# ----------------------------------------
# First train_day: 0	 Last train_day: 944
# First val_day: 945	 Last val_day: 1133
# ----------------------------------------
# 1 FOLDS: ElasticNet MAPE: 0.1590
# 2 FOLDS: ElasticNet MAPE: 0.1841
# 3 FOLDS: ElasticNet MAPE: 0.3220
# 4 FOLDS: ElasticNet MAPE: 0.2573
# 5 FOLDS: ElasticNet MAPE: 0.3183
#
# ElasticNet mean MAPE: 0.2481
# ========================================
# (1134, 19) (1134,) (294, 19) (294,)
# DecisionTreeRegressor Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 109.10it/s]
# First train_day: 0	 Last train_day: 188
# First val_day: 189	 Last val_day: 377
# ----------------------------------------
# First train_day: 0	 Last train_day: 377
# First val_day: 378	 Last val_day: 566
# ----------------------------------------
# First train_day: 0	 Last train_day: 566
# First val_day: 567	 Last val_day: 755
# ----------------------------------------
# First train_day: 0	 Last train_day: 755
# First val_day: 756	 Last val_day: 944
# ----------------------------------------
# First train_day: 0	 Last train_day: 944
# First val_day: 945	 Last val_day: 1133
# ----------------------------------------
# 1 FOLDS: DecisionTreeRegressor MAPE: 0.2631
# 2 FOLDS: DecisionTreeRegressor MAPE: 0.1794
# 3 FOLDS: DecisionTreeRegressor MAPE: 0.3098
# 4 FOLDS: DecisionTreeRegressor MAPE: 0.2959
# 5 FOLDS: DecisionTreeRegressor MAPE: 0.3352
#
# DecisionTreeRegressor mean MAPE: 0.2767
# ========================================
# (1134, 19) (1134,) (294, 19) (294,)
# RandomForestRegressor Cross Validations...:  10%|█         | 1/10 [00:00<00:01,  5.38it/s]
# First train_day: 0	 Last train_day: 188
# First val_day: 189	 Last val_day: 377
# ----------------------------------------
# First train_day: 0	 Last train_day: 377
# First val_day: 378	 Last val_day: 566
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  20%|██        | 2/10 [00:00<00:02,  3.92it/s]
# First train_day: 0	 Last train_day: 566
# First val_day: 567	 Last val_day: 755
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  30%|███       | 3/10 [00:00<00:02,  2.75it/s]
# First train_day: 0	 Last train_day: 755
# First val_day: 756	 Last val_day: 944
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  40%|████      | 4/10 [00:01<00:02,  2.15it/s]
# First train_day: 0	 Last train_day: 944
# First val_day: 945	 Last val_day: 1133
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  50%|█████     | 5/10 [00:02<00:02,  2.12it/s]
# 1 FOLDS: RandomForestRegressor MAPE: 0.1834
# 2 FOLDS: RandomForestRegressor MAPE: 0.0995
# 3 FOLDS: RandomForestRegressor MAPE: 0.3143
# 4 FOLDS: RandomForestRegressor MAPE: 0.2047
# 5 FOLDS: RandomForestRegressor MAPE: 0.3500
#
# RandomForestRegressor mean MAPE: 0.2304
# ========================================
# (1134, 19) (1134,) (294, 19) (294,)
# XGBRegressor Cross Validations...:  20%|██        | 2/10 [00:00<00:00, 15.37it/s]
# First train_day: 0	 Last train_day: 188
# First val_day: 189	 Last val_day: 377
# ----------------------------------------
# First train_day: 0	 Last train_day: 377
# First val_day: 378	 Last val_day: 566
# ----------------------------------------
# First train_day: 0	 Last train_day: 566
# First val_day: 567	 Last val_day: 755
# ----------------------------------------
# XGBRegressor Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 11.43it/s]
# First train_day: 0	 Last train_day: 755
# First val_day: 756	 Last val_day: 944
# ----------------------------------------
# First train_day: 0	 Last train_day: 944
# First val_day: 945	 Last val_day: 1133
# ----------------------------------------
# 1 FOLDS: XGBRegressor MAPE: 0.2661
# 2 FOLDS: XGBRegressor MAPE: 0.1013
# 3 FOLDS: XGBRegressor MAPE: 0.2955
# 4 FOLDS: XGBRegressor MAPE: 0.1980
# 5 FOLDS: XGBRegressor MAPE: 0.3295
#
# XGBRegressor mean MAPE: 0.2381
# ========================================
# (1134, 19) (1134,) (294, 19) (294,)
# LGBMRegressor Cross Validations...:  30%|███       | 3/10 [00:00<00:00, 25.84it/s]
# First train_day: 0	 Last train_day: 188
# First val_day: 189	 Last val_day: 377
# ----------------------------------------
# First train_day: 0	 Last train_day: 377
# First val_day: 378	 Last val_day: 566
# ----------------------------------------
# First train_day: 0	 Last train_day: 566
# First val_day: 567	 Last val_day: 755
# ----------------------------------------
# First train_day: 0	 Last train_day: 755
# First val_day: 756	 Last val_day: 944
# ----------------------------------------
# First train_day: 0	 Last train_day: 944
# First val_day: 945	 Last val_day: 1133
# ----------------------------------------
# LGBMRegressor Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 18.78it/s]
# 1 FOLDS: LGBMRegressor MAPE: 0.2234
# 2 FOLDS: LGBMRegressor MAPE: 0.0882
# 3 FOLDS: LGBMRegressor MAPE: 0.3219
# 4 FOLDS: LGBMRegressor MAPE: 0.2379
# 5 FOLDS: LGBMRegressor MAPE: 0.3749
#
# LGBMRegressor mean MAPE: 0.2493
# ========================================
#                    Model  Score
# 0       LinearRegression   0.23
# 1                  Ridge   0.23
# 2                  Lasso   0.23
# 3             ElasticNet   0.25
# 4  DecisionTreeRegressor   0.28
# 5  RandomForestRegressor   0.23
# 6           XGBRegressor   0.24
# 7          LGBMRegressor   0.25
# (1137, 19) (1137,) (293, 19) (293,)
# LinearRegression Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 249.77it/s]
# First train_day: 0	 Last train_day: 191
# First val_day: 192	 Last val_day: 380
# ----------------------------------------
# First train_day: 0	 Last train_day: 380
# First val_day: 381	 Last val_day: 569
# ----------------------------------------
# First train_day: 0	 Last train_day: 569
# First val_day: 570	 Last val_day: 758
# ----------------------------------------
# First train_day: 0	 Last train_day: 758
# First val_day: 759	 Last val_day: 947
# ----------------------------------------
# First train_day: 0	 Last train_day: 947
# First val_day: 948	 Last val_day: 1136
# ----------------------------------------
# 1 FOLDS: LinearRegression MAPE: 0.2225
# 2 FOLDS: LinearRegression MAPE: 0.2510
# 3 FOLDS: LinearRegression MAPE: 0.3283
# 4 FOLDS: LinearRegression MAPE: 0.2293
# 5 FOLDS: LinearRegression MAPE: 0.2104
#
# LinearRegression mean MAPE: 0.2483
# ========================================
# (1137, 19) (1137,) (293, 19) (293,)
# Ridge Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 283.63it/s]
# First train_day: 0	 Last train_day: 191
# First val_day: 192	 Last val_day: 380
# ----------------------------------------
# First train_day: 0	 Last train_day: 380
# First val_day: 381	 Last val_day: 569
# ----------------------------------------
# First train_day: 0	 Last train_day: 569
# First val_day: 570	 Last val_day: 758
# ----------------------------------------
# First train_day: 0	 Last train_day: 758
# First val_day: 759	 Last val_day: 947
# ----------------------------------------
# First train_day: 0	 Last train_day: 947
# First val_day: 948	 Last val_day: 1136
# ----------------------------------------
# 1 FOLDS: Ridge MAPE: 0.2247
# 2 FOLDS: Ridge MAPE: 0.2530
# 3 FOLDS: Ridge MAPE: 0.3214
# 4 FOLDS: Ridge MAPE: 0.2284
# 5 FOLDS: Ridge MAPE: 0.2103
#
# Ridge mean MAPE: 0.2476
# ========================================
# (1137, 19) (1137,) (293, 19) (293,)
# Lasso Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 117.17it/s]
# First train_day: 0	 Last train_day: 191
# First val_day: 192	 Last val_day: 380
# ----------------------------------------
# First train_day: 0	 Last train_day: 380
# First val_day: 381	 Last val_day: 569
# ----------------------------------------
# First train_day: 0	 Last train_day: 569
# First val_day: 570	 Last val_day: 758
# ----------------------------------------
# First train_day: 0	 Last train_day: 758
# First val_day: 759	 Last val_day: 947
# ----------------------------------------
# First train_day: 0	 Last train_day: 947
# First val_day: 948	 Last val_day: 1136
# ----------------------------------------
# 1 FOLDS: Lasso MAPE: 0.2210
# 2 FOLDS: Lasso MAPE: 0.2528
# 3 FOLDS: Lasso MAPE: 0.3148
# 4 FOLDS: Lasso MAPE: 0.2286
# 5 FOLDS: Lasso MAPE: 0.2109
#
# Lasso mean MAPE: 0.2456
# ========================================
# (1137, 19) (1137,) (293, 19) (293,)
# ElasticNet Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 298.10it/s]
# First train_day: 0	 Last train_day: 191
# First val_day: 192	 Last val_day: 380
# ----------------------------------------
# First train_day: 0	 Last train_day: 380
# First val_day: 381	 Last val_day: 569
# ----------------------------------------
# First train_day: 0	 Last train_day: 569
# First val_day: 570	 Last val_day: 758
# ----------------------------------------
# First train_day: 0	 Last train_day: 758
# First val_day: 759	 Last val_day: 947
# ----------------------------------------
# First train_day: 0	 Last train_day: 947
# First val_day: 948	 Last val_day: 1136
# ----------------------------------------
# 1 FOLDS: ElasticNet MAPE: 0.2366
# 2 FOLDS: ElasticNet MAPE: 0.2845
# 3 FOLDS: ElasticNet MAPE: 0.3309
# 4 FOLDS: ElasticNet MAPE: 0.2508
# 5 FOLDS: ElasticNet MAPE: 0.2211
#
# ElasticNet mean MAPE: 0.2648
# ========================================
# (1137, 19) (1137,) (293, 19) (293,)
# DecisionTreeRegressor Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 116.61it/s]
# First train_day: 0	 Last train_day: 191
# First val_day: 192	 Last val_day: 380
# ----------------------------------------
# First train_day: 0	 Last train_day: 380
# First val_day: 381	 Last val_day: 569
# ----------------------------------------
# First train_day: 0	 Last train_day: 569
# First val_day: 570	 Last val_day: 758
# ----------------------------------------
# First train_day: 0	 Last train_day: 758
# First val_day: 759	 Last val_day: 947
# ----------------------------------------
# First train_day: 0	 Last train_day: 947
# First val_day: 948	 Last val_day: 1136
# ----------------------------------------
# 1 FOLDS: DecisionTreeRegressor MAPE: 0.2541
# 2 FOLDS: DecisionTreeRegressor MAPE: 0.2748
# 3 FOLDS: DecisionTreeRegressor MAPE: 0.4262
# 4 FOLDS: DecisionTreeRegressor MAPE: 0.2639
# 5 FOLDS: DecisionTreeRegressor MAPE: 0.3263
#
# DecisionTreeRegressor mean MAPE: 0.3091
# ========================================
# (1137, 19) (1137,) (293, 19) (293,)
# RandomForestRegressor Cross Validations...:  10%|█         | 1/10 [00:00<00:01,  5.23it/s]
# First train_day: 0	 Last train_day: 191
# First val_day: 192	 Last val_day: 380
# ----------------------------------------
# First train_day: 0	 Last train_day: 380
# First val_day: 381	 Last val_day: 569
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  20%|██        | 2/10 [00:00<00:02,  3.72it/s]
# First train_day: 0	 Last train_day: 569
# First val_day: 570	 Last val_day: 758
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  30%|███       | 3/10 [00:00<00:02,  2.85it/s]
# First train_day: 0	 Last train_day: 758
# First val_day: 759	 Last val_day: 947
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  40%|████      | 4/10 [00:01<00:02,  2.25it/s]
# First train_day: 0	 Last train_day: 947
# First val_day: 948	 Last val_day: 1136
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  50%|█████     | 5/10 [00:02<00:02,  2.18it/s]
# 1 FOLDS: RandomForestRegressor MAPE: 0.2285
# 2 FOLDS: RandomForestRegressor MAPE: 0.2296
# 3 FOLDS: RandomForestRegressor MAPE: 0.4233
# 4 FOLDS: RandomForestRegressor MAPE: 0.2271
# 5 FOLDS: RandomForestRegressor MAPE: 0.3130
#
# RandomForestRegressor mean MAPE: 0.2843
# ========================================
# (1137, 19) (1137,) (293, 19) (293,)
# XGBRegressor Cross Validations...:  20%|██        | 2/10 [00:00<00:00, 14.59it/s]
# First train_day: 0	 Last train_day: 191
# First val_day: 192	 Last val_day: 380
# ----------------------------------------
# First train_day: 0	 Last train_day: 380
# First val_day: 381	 Last val_day: 569
# ----------------------------------------
# First train_day: 0	 Last train_day: 569
# First val_day: 570	 Last val_day: 758
# ----------------------------------------
# XGBRegressor Cross Validations...:  40%|████      | 4/10 [00:00<00:00, 11.62it/s]
# First train_day: 0	 Last train_day: 758
# First val_day: 759	 Last val_day: 947
# ----------------------------------------
# First train_day: 0	 Last train_day: 947
# First val_day: 948	 Last val_day: 1136
# ----------------------------------------
# XGBRegressor Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 11.14it/s]
# 1 FOLDS: XGBRegressor MAPE: 0.2385
# 2 FOLDS: XGBRegressor MAPE: 0.2176
# 3 FOLDS: XGBRegressor MAPE: 0.4222
# 4 FOLDS: XGBRegressor MAPE: 0.2195
# 5 FOLDS: XGBRegressor MAPE: 0.3306
#
# XGBRegressor mean MAPE: 0.2857
# ========================================
# (1137, 19) (1137,) (293, 19) (293,)
# LGBMRegressor Cross Validations...:  30%|███       | 3/10 [00:00<00:00, 25.03it/s]
# First train_day: 0	 Last train_day: 191
# First val_day: 192	 Last val_day: 380
# ----------------------------------------
# First train_day: 0	 Last train_day: 380
# First val_day: 381	 Last val_day: 569
# ----------------------------------------
# First train_day: 0	 Last train_day: 569
# First val_day: 570	 Last val_day: 758
# ----------------------------------------
# First train_day: 0	 Last train_day: 758
# First val_day: 759	 Last val_day: 947
# ----------------------------------------
# LGBMRegressor Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 12.40it/s]
# First train_day: 0	 Last train_day: 947
# First val_day: 948	 Last val_day: 1136
# ----------------------------------------
# 1 FOLDS: LGBMRegressor MAPE: 0.2221
# 2 FOLDS: LGBMRegressor MAPE: 0.2191
# 3 FOLDS: LGBMRegressor MAPE: 0.4019
# 4 FOLDS: LGBMRegressor MAPE: 0.2231
# 5 FOLDS: LGBMRegressor MAPE: 0.3187
#
# LGBMRegressor mean MAPE: 0.2770
# ========================================
#                    Model  Score
# 0       LinearRegression   0.25
# 1                  Ridge   0.25
# 2                  Lasso   0.25
# 3             ElasticNet   0.26
# 4  DecisionTreeRegressor   0.31
# 5  RandomForestRegressor   0.28
# 6           XGBRegressor   0.29
# 7          LGBMRegressor   0.28
# (1130, 19) (1130,) (289, 19) (289,)
# LinearRegression Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 293.84it/s]
# First train_day: 0	 Last train_day: 189
# First val_day: 190	 Last val_day: 377
# ----------------------------------------
# First train_day: 0	 Last train_day: 377
# First val_day: 378	 Last val_day: 565
# ----------------------------------------
# First train_day: 0	 Last train_day: 565
# First val_day: 566	 Last val_day: 753
# ----------------------------------------
# First train_day: 0	 Last train_day: 753
# First val_day: 754	 Last val_day: 941
# ----------------------------------------
# First train_day: 0	 Last train_day: 941
# First val_day: 942	 Last val_day: 1129
# ----------------------------------------
# 1 FOLDS: LinearRegression MAPE: 0.0885
# 2 FOLDS: LinearRegression MAPE: 0.1231
# 3 FOLDS: LinearRegression MAPE: 0.1354
# 4 FOLDS: LinearRegression MAPE: 0.0627
# 5 FOLDS: LinearRegression MAPE: 0.2381
#
# LinearRegression mean MAPE: 0.1296
# ========================================
# (1130, 19) (1130,) (289, 19) (289,)
# Ridge Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 334.74it/s]
# First train_day: 0	 Last train_day: 189
# First val_day: 190	 Last val_day: 377
# ----------------------------------------
# First train_day: 0	 Last train_day: 377
# First val_day: 378	 Last val_day: 565
# ----------------------------------------
# First train_day: 0	 Last train_day: 565
# First val_day: 566	 Last val_day: 753
# ----------------------------------------
# First train_day: 0	 Last train_day: 753
# First val_day: 754	 Last val_day: 941
# ----------------------------------------
# First train_day: 0	 Last train_day: 941
# First val_day: 942	 Last val_day: 1129
# ----------------------------------------
# 1 FOLDS: Ridge MAPE: 0.0895
# 2 FOLDS: Ridge MAPE: 0.1392
# 3 FOLDS: Ridge MAPE: 0.1354
# 4 FOLDS: Ridge MAPE: 0.0618
# 5 FOLDS: Ridge MAPE: 0.2240
#
# Ridge mean MAPE: 0.1300
# ========================================
# (1130, 19) (1130,) (289, 19) (289,)
# Lasso Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 139.30it/s]
# First train_day: 0	 Last train_day: 189
# First val_day: 190	 Last val_day: 377
# ----------------------------------------
# First train_day: 0	 Last train_day: 377
# First val_day: 378	 Last val_day: 565
# ----------------------------------------
# First train_day: 0	 Last train_day: 565
# First val_day: 566	 Last val_day: 753
# ----------------------------------------
# First train_day: 0	 Last train_day: 753
# First val_day: 754	 Last val_day: 941
# ----------------------------------------
# First train_day: 0	 Last train_day: 941
# First val_day: 942	 Last val_day: 1129
# ----------------------------------------
# 1 FOLDS: Lasso MAPE: 0.0885
# 2 FOLDS: Lasso MAPE: 0.1331
# 3 FOLDS: Lasso MAPE: 0.1345
# 4 FOLDS: Lasso MAPE: 0.0621
# 5 FOLDS: Lasso MAPE: 0.2276
#
# Lasso mean MAPE: 0.1292
# ========================================
# (1130, 19) (1130,) (289, 19) (289,)
# ElasticNet Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 333.04it/s]
# First train_day: 0	 Last train_day: 189
# First val_day: 190	 Last val_day: 377
# ----------------------------------------
# First train_day: 0	 Last train_day: 377
# First val_day: 378	 Last val_day: 565
# ----------------------------------------
# First train_day: 0	 Last train_day: 565
# First val_day: 566	 Last val_day: 753
# ----------------------------------------
# First train_day: 0	 Last train_day: 753
# First val_day: 754	 Last val_day: 941
# ----------------------------------------
# First train_day: 0	 Last train_day: 941
# First val_day: 942	 Last val_day: 1129
# ----------------------------------------
# 1 FOLDS: ElasticNet MAPE: 0.0992
# 2 FOLDS: ElasticNet MAPE: 0.1455
# 3 FOLDS: ElasticNet MAPE: 0.1647
# 4 FOLDS: ElasticNet MAPE: 0.0763
# 5 FOLDS: ElasticNet MAPE: 0.2685
#
# ElasticNet mean MAPE: 0.1508
# ========================================
# (1130, 19) (1130,) (289, 19) (289,)
# DecisionTreeRegressor Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 114.27it/s]
# First train_day: 0	 Last train_day: 189
# First val_day: 190	 Last val_day: 377
# ----------------------------------------
# First train_day: 0	 Last train_day: 377
# First val_day: 378	 Last val_day: 565
# ----------------------------------------
# First train_day: 0	 Last train_day: 565
# First val_day: 566	 Last val_day: 753
# ----------------------------------------
# First train_day: 0	 Last train_day: 753
# First val_day: 754	 Last val_day: 941
# ----------------------------------------
# First train_day: 0	 Last train_day: 941
# First val_day: 942	 Last val_day: 1129
# ----------------------------------------
# 1 FOLDS: DecisionTreeRegressor MAPE: 0.0889
# 2 FOLDS: DecisionTreeRegressor MAPE: 0.2025
# 3 FOLDS: DecisionTreeRegressor MAPE: 0.1601
# 4 FOLDS: DecisionTreeRegressor MAPE: 0.1447
# 5 FOLDS: DecisionTreeRegressor MAPE: 0.4488
#
# DecisionTreeRegressor mean MAPE: 0.2090
# ========================================
# (1130, 19) (1130,) (289, 19) (289,)
# RandomForestRegressor Cross Validations...:  10%|█         | 1/10 [00:00<00:01,  5.42it/s]
# First train_day: 0	 Last train_day: 189
# First val_day: 190	 Last val_day: 377
# ----------------------------------------
# First train_day: 0	 Last train_day: 377
# First val_day: 378	 Last val_day: 565
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  20%|██        | 2/10 [00:00<00:02,  3.92it/s]
# First train_day: 0	 Last train_day: 565
# First val_day: 566	 Last val_day: 753
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  30%|███       | 3/10 [00:00<00:02,  2.96it/s]
# First train_day: 0	 Last train_day: 753
# First val_day: 754	 Last val_day: 941
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  40%|████      | 4/10 [00:01<00:02,  2.30it/s]
# First train_day: 0	 Last train_day: 941
# First val_day: 942	 Last val_day: 1129
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  50%|█████     | 5/10 [00:02<00:02,  2.21it/s]
# 1 FOLDS: RandomForestRegressor MAPE: 0.0675
# 2 FOLDS: RandomForestRegressor MAPE: 0.1798
# 3 FOLDS: RandomForestRegressor MAPE: 0.1558
# 4 FOLDS: RandomForestRegressor MAPE: 0.1159
# 5 FOLDS: RandomForestRegressor MAPE: 0.4339
#
# RandomForestRegressor mean MAPE: 0.1906
# ========================================
# (1130, 19) (1130,) (289, 19) (289,)
# XGBRegressor Cross Validations...:  20%|██        | 2/10 [00:00<00:00, 12.57it/s]
# First train_day: 0	 Last train_day: 189
# First val_day: 190	 Last val_day: 377
# ----------------------------------------
# First train_day: 0	 Last train_day: 377
# First val_day: 378	 Last val_day: 565
# ----------------------------------------
# First train_day: 0	 Last train_day: 565
# First val_day: 566	 Last val_day: 753
# ----------------------------------------
# XGBRegressor Cross Validations...:  40%|████      | 4/10 [00:00<00:00, 10.16it/s]
# First train_day: 0	 Last train_day: 753
# First val_day: 754	 Last val_day: 941
# ----------------------------------------
# First train_day: 0	 Last train_day: 941
# First val_day: 942	 Last val_day: 1129
# ----------------------------------------
# XGBRegressor Cross Validations...:  50%|█████     | 5/10 [00:00<00:00,  9.83it/s]
# 1 FOLDS: XGBRegressor MAPE: 0.0721
# 2 FOLDS: XGBRegressor MAPE: 0.1765
# 3 FOLDS: XGBRegressor MAPE: 0.1563
# 4 FOLDS: XGBRegressor MAPE: 0.1279
# 5 FOLDS: XGBRegressor MAPE: 0.4142
#
# XGBRegressor mean MAPE: 0.1894
# ========================================
# (1130, 19) (1130,) (289, 19) (289,)
# LGBMRegressor Cross Validations...:  30%|███       | 3/10 [00:00<00:00, 26.80it/s]
# First train_day: 0	 Last train_day: 189
# First val_day: 190	 Last val_day: 377
# ----------------------------------------
# First train_day: 0	 Last train_day: 377
# First val_day: 378	 Last val_day: 565
# ----------------------------------------
# First train_day: 0	 Last train_day: 565
# First val_day: 566	 Last val_day: 753
# ----------------------------------------
# First train_day: 0	 Last train_day: 753
# First val_day: 754	 Last val_day: 941
# ----------------------------------------
# First train_day: 0	 Last train_day: 941
# First val_day: 942	 Last val_day: 1129
# ----------------------------------------
# LGBMRegressor Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 19.04it/s]
# 1 FOLDS: LGBMRegressor MAPE: 0.0717
# 2 FOLDS: LGBMRegressor MAPE: 0.1771
# 3 FOLDS: LGBMRegressor MAPE: 0.1583
# 4 FOLDS: LGBMRegressor MAPE: 0.1298
# 5 FOLDS: LGBMRegressor MAPE: 0.4287
#
# LGBMRegressor mean MAPE: 0.1931
# ========================================
#                    Model  Score
# 0       LinearRegression   0.13
# 1                  Ridge   0.13
# 2                  Lasso   0.13
# 3             ElasticNet   0.15
# 4  DecisionTreeRegressor   0.21
# 5  RandomForestRegressor   0.19
# 6           XGBRegressor   0.19
# 7          LGBMRegressor   0.19
# (1121, 19) (1121,) (288, 19) (288,)
# LinearRegression Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 296.18it/s]
# First train_day: 0	 Last train_day: 190
# First val_day: 191	 Last val_day: 376
# ----------------------------------------
# First train_day: 0	 Last train_day: 376
# First val_day: 377	 Last val_day: 562
# ----------------------------------------
# First train_day: 0	 Last train_day: 562
# First val_day: 563	 Last val_day: 748
# ----------------------------------------
# First train_day: 0	 Last train_day: 748
# First val_day: 749	 Last val_day: 934
# ----------------------------------------
# First train_day: 0	 Last train_day: 934
# First val_day: 935	 Last val_day: 1120
# ----------------------------------------
# 1 FOLDS: LinearRegression MAPE: 0.1554
# 2 FOLDS: LinearRegression MAPE: 0.3265
# 3 FOLDS: LinearRegression MAPE: 0.4037
# 4 FOLDS: LinearRegression MAPE: 0.2324
# 5 FOLDS: LinearRegression MAPE: 0.1878
#
# LinearRegression mean MAPE: 0.2612
# ========================================
# (1121, 19) (1121,) (288, 19) (288,)
# Ridge Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 337.85it/s]
# First train_day: 0	 Last train_day: 190
# First val_day: 191	 Last val_day: 376
# ----------------------------------------
# First train_day: 0	 Last train_day: 376
# First val_day: 377	 Last val_day: 562
# ----------------------------------------
# First train_day: 0	 Last train_day: 562
# First val_day: 563	 Last val_day: 748
# ----------------------------------------
# First train_day: 0	 Last train_day: 748
# First val_day: 749	 Last val_day: 934
# ----------------------------------------
# First train_day: 0	 Last train_day: 934
# First val_day: 935	 Last val_day: 1120
# ----------------------------------------
# 1 FOLDS: Ridge MAPE: 0.1486
# 2 FOLDS: Ridge MAPE: 0.3337
# 3 FOLDS: Ridge MAPE: 0.4028
# 4 FOLDS: Ridge MAPE: 0.2325
# 5 FOLDS: Ridge MAPE: 0.1875
#
# Ridge mean MAPE: 0.2610
# ========================================
# (1121, 19) (1121,) (288, 19) (288,)
# Lasso Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 141.48it/s]
# First train_day: 0	 Last train_day: 190
# First val_day: 191	 Last val_day: 376
# ----------------------------------------
# First train_day: 0	 Last train_day: 376
# First val_day: 377	 Last val_day: 562
# ----------------------------------------
# First train_day: 0	 Last train_day: 562
# First val_day: 563	 Last val_day: 748
# ----------------------------------------
# First train_day: 0	 Last train_day: 748
# First val_day: 749	 Last val_day: 934
# ----------------------------------------
# First train_day: 0	 Last train_day: 934
# First val_day: 935	 Last val_day: 1120
# ----------------------------------------
# 1 FOLDS: Lasso MAPE: 0.1507
# 2 FOLDS: Lasso MAPE: 0.3250
# 3 FOLDS: Lasso MAPE: 0.4031
# 4 FOLDS: Lasso MAPE: 0.2320
# 5 FOLDS: Lasso MAPE: 0.1876
#
# Lasso mean MAPE: 0.2597
# ========================================
# (1121, 19) (1121,) (288, 19) (288,)
# ElasticNet Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 302.81it/s]
# First train_day: 0	 Last train_day: 190
# First val_day: 191	 Last val_day: 376
# ----------------------------------------
# First train_day: 0	 Last train_day: 376
# First val_day: 377	 Last val_day: 562
# ----------------------------------------
# First train_day: 0	 Last train_day: 562
# First val_day: 563	 Last val_day: 748
# ----------------------------------------
# First train_day: 0	 Last train_day: 748
# First val_day: 749	 Last val_day: 934
# ----------------------------------------
# First train_day: 0	 Last train_day: 934
# First val_day: 935	 Last val_day: 1120
# ----------------------------------------
# 1 FOLDS: ElasticNet MAPE: 0.1446
# 2 FOLDS: ElasticNet MAPE: 0.3763
# 3 FOLDS: ElasticNet MAPE: 0.4258
# 4 FOLDS: ElasticNet MAPE: 0.2396
# 5 FOLDS: ElasticNet MAPE: 0.1848
#
# ElasticNet mean MAPE: 0.2742
# ========================================
# (1121, 19) (1121,) (288, 19) (288,)
# DecisionTreeRegressor Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 99.12it/s]
# First train_day: 0	 Last train_day: 190
# First val_day: 191	 Last val_day: 376
# ----------------------------------------
# First train_day: 0	 Last train_day: 376
# First val_day: 377	 Last val_day: 562
# ----------------------------------------
# First train_day: 0	 Last train_day: 562
# First val_day: 563	 Last val_day: 748
# ----------------------------------------
# First train_day: 0	 Last train_day: 748
# First val_day: 749	 Last val_day: 934
# ----------------------------------------
# First train_day: 0	 Last train_day: 934
# First val_day: 935	 Last val_day: 1120
# ----------------------------------------
# 1 FOLDS: DecisionTreeRegressor MAPE: 0.2052
# 2 FOLDS: DecisionTreeRegressor MAPE: 0.4464
# 3 FOLDS: DecisionTreeRegressor MAPE: 0.7416
# 4 FOLDS: DecisionTreeRegressor MAPE: 0.3933
# 5 FOLDS: DecisionTreeRegressor MAPE: 0.2913
#
# DecisionTreeRegressor mean MAPE: 0.4156
# ========================================
# (1121, 19) (1121,) (288, 19) (288,)
# RandomForestRegressor Cross Validations...:  10%|█         | 1/10 [00:00<00:01,  5.05it/s]
# First train_day: 0	 Last train_day: 190
# First val_day: 191	 Last val_day: 376
# ----------------------------------------
# First train_day: 0	 Last train_day: 376
# First val_day: 377	 Last val_day: 562
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  20%|██        | 2/10 [00:00<00:02,  3.48it/s]
# First train_day: 0	 Last train_day: 562
# First val_day: 563	 Last val_day: 748
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  30%|███       | 3/10 [00:01<00:02,  2.55it/s]
# First train_day: 0	 Last train_day: 748
# First val_day: 749	 Last val_day: 934
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  40%|████      | 4/10 [00:01<00:02,  2.04it/s]
# First train_day: 0	 Last train_day: 934
# First val_day: 935	 Last val_day: 1120
# ----------------------------------------
# RandomForestRegressor Cross Validations...:  50%|█████     | 5/10 [00:02<00:02,  1.99it/s]
# 1 FOLDS: RandomForestRegressor MAPE: 0.1549
# 2 FOLDS: RandomForestRegressor MAPE: 0.3770
# 3 FOLDS: RandomForestRegressor MAPE: 0.6179
# 4 FOLDS: RandomForestRegressor MAPE: 0.2992
# 5 FOLDS: RandomForestRegressor MAPE: 0.2309
#
# RandomForestRegressor mean MAPE: 0.3360
# ========================================
# (1121, 19) (1121,) (288, 19) (288,)
# XGBRegressor Cross Validations...:  10%|█         | 1/10 [00:00<00:00,  9.99it/s]
# First train_day: 0	 Last train_day: 190
# First val_day: 191	 Last val_day: 376
# ----------------------------------------
# First train_day: 0	 Last train_day: 376
# First val_day: 377	 Last val_day: 562
# ----------------------------------------
# First train_day: 0	 Last train_day: 562
# First val_day: 563	 Last val_day: 748
# ----------------------------------------
# XGBRegressor Cross Validations...:  30%|███       | 3/10 [00:00<00:00, 11.48it/s]
# First train_day: 0	 Last train_day: 748
# First val_day: 749	 Last val_day: 934
# ----------------------------------------
# First train_day: 0	 Last train_day: 934
# First val_day: 935	 Last val_day: 1120
# ----------------------------------------
# XGBRegressor Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 10.34it/s]
# 1 FOLDS: XGBRegressor MAPE: 0.1650
# 2 FOLDS: XGBRegressor MAPE: 0.4260
# 3 FOLDS: XGBRegressor MAPE: 0.5421
# 4 FOLDS: XGBRegressor MAPE: 0.3471
# 5 FOLDS: XGBRegressor MAPE: 0.2352
#
# XGBRegressor mean MAPE: 0.3431
# ========================================
# (1121, 19) (1121,) (288, 19) (288,)
# LGBMRegressor Cross Validations...:  30%|███       | 3/10 [00:00<00:00, 27.50it/s]
# First train_day: 0	 Last train_day: 190
# First val_day: 191	 Last val_day: 376
# ----------------------------------------
# First train_day: 0	 Last train_day: 376
# First val_day: 377	 Last val_day: 562
# ----------------------------------------
# First train_day: 0	 Last train_day: 562
# First val_day: 563	 Last val_day: 748
# ----------------------------------------
# First train_day: 0	 Last train_day: 748
# First val_day: 749	 Last val_day: 934
# ----------------------------------------
# First train_day: 0	 Last train_day: 934
# First val_day: 935	 Last val_day: 1120
# ----------------------------------------
# LGBMRegressor Cross Validations...:  50%|█████     | 5/10 [00:00<00:00, 19.67it/s]
# 1 FOLDS: LGBMRegressor MAPE: 0.1639
# 2 FOLDS: LGBMRegressor MAPE: 0.4066
# 3 FOLDS: LGBMRegressor MAPE: 0.6259
# 4 FOLDS: LGBMRegressor MAPE: 0.3519
# 5 FOLDS: LGBMRegressor MAPE: 0.2329
#
# LGBMRegressor mean MAPE: 0.3562
# ========================================
#                    Model  Score
# 0       LinearRegression   0.26
# 1                  Ridge   0.26
# 2                  Lasso   0.26
# 3             ElasticNet   0.27
# 4  DecisionTreeRegressor   0.42
# 5  RandomForestRegressor   0.34
# 6           XGBRegressor   0.34
# 7          LGBMRegressor   0.36

# %%
for pum in df.PUM_NM.unique() :
    train_X, test_X, train_y, test_y = pre_2(df, pum, 7)
    print(f'{pum}')

    cut = int(len(train_X)*0.8)

    h_train_X = train_X[:cut]
    h_train_y = train_y[:cut]

    h_valid_X = train_X[cut:]
    h_valid_y = train_y[cut:]

    print(h_train_X.shape, h_train_y.shape, h_valid_X.shape, h_valid_y.shape)


    # 2주 예측은 LR 모델로 진행
    model = LinearRegression()
    lr_model = model.fit(h_train_X, h_train_y)
    lr_pred = lr_model.predict(test_X)
    mape = MAPE(test_y, lr_pred)
    print(lr_pred.shape, test_y.shape)
    print(f'{pum} default LR model MAPE :', mape)

    # feature importances 그래프를 위해 lightGBM 모델 사용
    model2 = LGBMRegressor()
    lgb_model = model2.fit(h_train_X, h_train_y, eval_set=[(h_valid_X, h_valid_y)], verbose=0, early_stopping_rounds=25)
    lgb_pred = lgb_model.predict(test_X)
    mape2 = MAPE(test_y, lgb_pred)
    print(lgb_pred.shape, test_y.shape)
    print(f'{pum} default LGBM model MAPE :', mape2)

    # 실제값 예측값 시각화(LR 모델이 잘나와서 LR 모델로 예측한 값 시각화)
    plt.figure(figsize = (15,5))
    plt.plot(lr_pred, label = 'predicted')
    plt.plot(np.array(test_y), label = 'Actual')
    plt.legend()
    plt.title(f'{pum} LR Predicted VS Actual (4week_predict)', fontsize = 15)
    plt.show()

    # LightGBM feature importances 시각화
    plt.figure(figsize = (10,8))
    plt.barh(train_X.columns, lgb_model.feature_importances_)
    plt.title(f'{pum} LightGBM feature importances (4week_predict)', fontsize = 15)
    plt.show()
# Out:
# (1138, 19) (1138,) (293, 19) (293,)
# 사과
# (910, 19) (910,) (228, 19) (228,)
# (293,) (293,)
# 사과 default LR model MAPE : 0.23662668794819347
# (293,) (293,)
# 사과 default LGBM model MAPE : 0.2596147472661823
# (1138, 19) (1138,) (293, 19) (293,)
# 배추
# (910, 19) (910,) (228, 19) (228,)
# (293,) (293,)
# 배추 default LR model MAPE : 0.23685401706769568
# (293,) (293,)
# 배추 default LGBM model MAPE : 0.23537999449448965
# (1138, 19) (1138,) (292, 19) (292,)
# 무
# (910, 19) (910,) (228, 19) (228,)
# (292,) (292,)
# 무 default LR model MAPE : 0.2761988174476153
# (292,) (292,)
# 무 default LGBM model MAPE : 0.32691318215201903
# (1134, 19) (1134,) (294, 19) (294,)
# 양파
# (907, 19) (907,) (227, 19) (227,)
# (294,) (294,)
# 양파 default LR model MAPE : 0.1614612912353339
# (294,) (294,)
# 양파 default LGBM model MAPE : 0.16400114675943125
# (1137, 19) (1137,) (293, 19) (293,)
# 대파
# (909, 19) (909,) (228, 19) (228,)
# (293,) (293,)
# 대파 default LR model MAPE : 0.24875772967180507
# (293,) (293,)
# 대파 default LGBM model MAPE : 0.3041829481099955
# (1130, 19) (1130,) (289, 19) (289,)
# 마늘
# (904, 19) (904,) (226, 19) (226,)
# (289,) (289,)
# 마늘 default LR model MAPE : 0.21393803142761847
# (289,) (289,)
# 마늘 default LGBM model MAPE : 0.45903662963141706
# (1121, 19) (1121,) (288, 19) (288,)
# 건고추
# (896, 19) (896,) (225, 19) (225,)
# (288,) (288,)
# 건고추 default LR model MAPE : 0.22419309669851956
# (288,) (288,)
# 건고추 default LGBM model MAPE : 0.24704377637204716
